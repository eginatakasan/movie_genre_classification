# %%
from os import path, listdir
import string
import re
import pandas as pd
import codecs
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.naive_bayes import MultinomialNB

# %%
genres = ['Action', 'Comedy', 'Crime', 'Horror', 'Musical', 'Romance', 'War', 'Western']
columns = ['File', 'Genre', 'Hearing Impaired Subtitle']
target_col = 'Genre'
subtitle_col = 'Hearing Impaired Subtitle'

train_subtitles_path = "subtitles/TrainSubtitles"
test_subtitles_path = "subtitles/TestSubtitles"

# %%
def make_dataframe(path):
    df = pd.DataFrame(columns = columns)
    for genre in genres:
        #get every dataset in genre
        genre_path = "%s/%s" % (path, genre)
        
        for f in listdir(genre_path):
            hearing_descriptions = []
            file_path = "%s/%s" % (genre_path, f)
            
            with codecs.open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
                #finds hearing descriptions
                for line in f:
                    res = re.findall(r'(\[.+\]|\(.+\))', line)
                    if res:
                        res[0] = re.sub(r'<.*?>', '', res[0])
                    hearing_descriptions.extend(list(res))
                #remove brackets
                hearing_descriptions = ' '.join([i[1:-1] for i in hearing_descriptions])
            data = {'File': file_path, 'Genre': genre, 'Hearing Impaired Subtitle': hearing_descriptions}
            df = df.append(data, ignore_index = True)
    return df

# %%
train_df = make_dataframe(train_subtitles_path)
test_df = make_dataframe(test_subtitles_path)

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
stop = set(stopwords.words('english'))
punc_table = str.maketrans('', '', string.punctuation)

def lowercase(text):
    return [i.lower() for i in text]

def eliminate_stopwords(text):
    return [word for word in text if word not in stopwords.words('english')]

def stem(text):
    return [stemmer.stem(word) for word in text]

def lemmatize(text):
    return [lemmatizer.lemmatize(word) for word in text]

def eliminate_punctuations(text):
    res = []
    stripped = [word.translate(punc_table) for word in text]
    for word in stripped:
        if (word):
            res.append(word)
    return res

def preprocess(text):
    res = word_tokenize(text)
    res = lowercase(res)
    res = eliminate_stopwords(res)
    res = lemmatize(res)
    return " ".join([word for word in res])
    
def preprocess_dataframe(df):
    df[subtitle_col] = df[subtitle_col].map(lambda s: preprocess(s))

# %%
preprocess_dataframe(train_df)
preprocess_dataframe(test_df)

# %%
#Vectorization
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(train_df[subtitle_col])
y_train = train_df[target_col]
X_test = vectorizer.transform(test_df[subtitle_col])
y_test = test_df[target_col]

print(vectorizer.get_feature_names())
# Out:
# ['00', '000', '002', '01', '09', '0ughs', '10', '100', '1000', '1024', '109', '11', '1117', '1122', '1189', '12', '123', '1245', '1246', '1267', '1296', '13', '1414', '1602', '1642', '165', '1678', '1737', '18', '1812', '182', '185', '187', '19', '190', '1920s', '1943', '1950', '1960', '1962', '1966', '1970s', '1975', '198', '1980s', '1994', '1996', '1998', '1999', '19th', '1g', '1st', '2000', '2002', '2004', '2009', '2010', '2011', '2015', '20th', '211', '227', '23', '230', '235', '238', '25', '270', '28', '29', '2nd', '30', '303', '316', '362', '3l', '3rd', '40', '400', '42nd', '43', '434', '47', '48', '500', '5309', '568', '569', '570', '59', '5th', '60', '6000', '60s', '626', '633', '66', '69', '70', '70s', '710', '719', '720', '729', '736', '744', '750', '752', '768', '770', '775', '776', '777', '778', '80', '800', '801', '803', '80s', '811', '815', '821', '824', '837', '838', '843', '846', '848', '849', '851', '867', '870', '871', '906', '90th', '93505', '93595', '9395', '976', '987', '988', '99', '99th', '9asps', '9i99le', '__', '_augh', '_aughs', '_es', '_oses', '_s', 'a_d', 'aahs', 'aardvark', 'aaron', 'abba', 'abbot', 'abbott', 'abby', 'abc', 'abdomen', 'abdul', 'abe', 'abel', 'abercrombie', 'abide', 'abigail', 'abin', 'abishag', 'abner', 'aboriginal', 'aborigine', 'abraham', 'abreu', 'abrupt', 'abruptly', 'absence', 'absent', 'absolutely', 'absoluteness', 'absurd', 'abu', 'abuse', 'ac', 'acapella', 'acarine', 'acb', 'accelerate', 'accelerated', 'accelerates', 'accelerating', 'acceleration', 'acceleratlng', 'accelerator', 'accent', 'accented', 'accessory', 'accidentally', 'acclamation', 'accompanied', 'accompaniment', 'accordion', 'account', 'ace', 'ache', 'aching', 'acid', 'ack', 'ackerman', 'acknowledgement', 'acknowledges', 'acorn', 'acoustic', 'acousttic', 'acquiesce', 'acreeinc', 'across', 'act', 'acting', 'action', 'activate', 'activates', 'activator', 'active', 'actor', 'actress', 'ad', 'ada', 'adagio', 'adam', 'adama', 'adamantium', 'adcox', 'addic7ed', 'adding', 'addison', 'address', 'addressing', 'adelaide', 'adele', 'adelita', 'adeste', 'adhara', 'adler', 'admiral', 'admire', 'admiringly', 'admonishingly', 'adolf', 'adonijah', 'adore', 'adored', 'adoringly', 'adrian', 'adriana', 'adrienne', 'adso', 'adult', 'advance', 'adventure', 'adventurous', 'advice', 'adèle', 'aeon', 'aerial', 'aeroplane', 'aetius', 'afar', 'affected', 'affectionate', 'affirm', 'affirmation', 'affirmativeiy', 'affirmatively', 'affirming', 'afford', 'afghani', 'afraid', 'african', 'afrikaans', 'afternoon', 'afvn', 'agador', 'agatha', 'age', 'agent', 'aggie', 'aggressive', 'aggressively', 'aghast', 'aghori', 'aghoris', 'agitated', 'agitatedly', 'agnes', 'agness', 'ago', 'agonised', 'agonized', 'agony', 'agree', 'agreeing', 'agreelng', 'agreement', 'agrees', 'agu', 'aguirre', 'ah', 'ahead', 'ahem', 'ahmad', 'ahmed', 'ai', 'aiarm', 'aid', 'aidan', 'aide', 'aii', 'ail', 'aimed', 'aimo', 'aiong', 'air', 'airborne', 'aircraft', 'airflow', 'airhorns', 'airlock', 'airman', 'airpiane', 'airplane', 'airport', 'airshin', 'aj', 'ajax', 'akes', 'akira', 'aklng', 'akut', 'akwid', 'al', 'alabama', 'aladdin', 'alan', 'alarm', 'alarmed', 'alarms', 'alba', 'albaby', 'albanian', 'albany', 'albert', 'alberto', 'albinoni', 'albrecht', 'album', 'alby', 'alcaino', 'alchemy', 'alcmene', 'alec', 'alejandro', 'aleksei', 'alert', 'alessa', 'alette', 'alex', 'alexa', 'alexander', 'alexandra', 'alexei', 'alexi', 'alfie', 'alfonso', 'alfred', 'alfredo', 'algonquian', 'algonquin', 'alhumming', 'ali', 'alice', 'alicia', 'alida', 'alien', 'alik', 'alisdair', 'alisha', 'alison', 'alissa', 'alive', 'all', 'allan', 'allen', 'allie', 'alligator', 'allison', 'allle', 'alllson', 'ally', 'alma', 'almasy', 'almine', 'almost', 'alms', 'alone', 'along', 'alongside', 'alonzo', 'aloud', 'alpha', 'alphabet', 'alr', 'already', 'alright', 'alrightplaying', 'alrplane', 'also', 'alspeaking', 'alspeakingjapanese', 'alsquawks', 'altered', 'alternating', 'alternative', 'altogether', 'alu ...

# %%
#find optimal alpha value
def get_optimal_alpha():
    alpha_values = [0.1, 0.5, 0.01, 0.05, 0.001, 0.005]
    acc_scores = []
    for a in alpha_values:
        clf = MultinomialNB(alpha=a)
        acc = 0
        clf.fit(X_train, y_train)

        predicted = clf.predict(X_test)
        acc += accuracy_score(y_test, predicted)*100
        acc_scores.append(float(acc/50))
    return alpha_values[acc_scores.index(max(acc_scores))]

optimal_alpha = get_optimal_alpha()

# %%
#fitting
nb_classifier = MultinomialNB(alpha=optimal_alpha).fit(X_train, y_train)

# %%
pred = nb_classifier.predict(X_test)
print(classification_report(y_test,pred))
print('Accuracy score: ', accuracy_score(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#       Action       0.25      0.23      0.24        88
#       Comedy       0.30      0.35      0.33       105
#        Crime       0.30      0.31      0.30        75
#       Horror       0.58      0.50      0.54        86
#      Musical       0.57      0.38      0.46        60
#      Romance       0.25      0.36      0.29        98
#          War       0.67      0.52      0.58        66
#      Western       0.82      0.71      0.76        52
#
#     accuracy                           0.40       630
#    macro avg       0.47      0.42      0.44       630
# weighted avg       0.43      0.40      0.41       630
#
# Accuracy score:  0.4
